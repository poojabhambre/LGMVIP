# %% [markdown]
# LGMVIP TASK 2 - Image to pencil sketch with python
#
# import the libraries

# %%
import numpy as np
import pandas as pd
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# Loading the image

# %%
image=cv2.imread("dog.jfif",1)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=204x247 at 0x7F508AF76DD0>

# %% [markdown]
# Converting an original image into gray-scale image

# %%
image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=204x247 at 0x7F5089053B90>

# %% [markdown]
# Inverting the image

# %%
image_invert=cv2.bitwise_not(image_gray)

# %%
cv2_imshow(image_invert)
# Out:
# <PIL.Image.Image image mode=L size=204x247 at 0x7F50890D8F10>

# %% [markdown]
# Blurring the image using Guassian blur

# %%
image_blur=cv2.GaussianBlur(image_invert,(21,21),sigmaX=0,sigmaY=0)

# %%
cv2_imshow(image_blur)
# Out:
# <PIL.Image.Image image mode=L size=204x247 at 0x7F508908DBD0>

# %% [markdown]
# Dividing the greyscale value of image by inverse of blurred image value

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# Final Image

# %%
final_image = dodgeV2(image_gray, image_blur)

# %%
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=L size=204x247 at 0x7F5089052190>
